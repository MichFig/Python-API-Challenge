# %% [markdown]
# ## WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# !pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\michelle\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\michelle\anaconda3\lib\site-packages (from citipy) (0.16)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import logging
import math

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

lat_lngs

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 631

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it's being processed (with the city number and city name).

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather?"
city = cities


query_url = f"{base_url}appid={weather_api_key}&q={city}&units=imperial"

# Get weather data
#weather_response = requests.get(query_url).json()

# %%
cities_results = []

#Conversion of Kelvin to Fahrenheit


for index,city in enumerate(cities):
    
    base_url = "http://api.openweathermap.org/data/2.5/weather?"
    query_url = f"{base_url}appid={weather_api_key}&q={city}&units=imperial"

    print(f'found {city}')
          
    try:
        # Get weather data
        weather_response = requests.get(query_url).json()
        lon=weather_response["coord"]["lon"]
        lat=weather_response["coord"]["lat"]
        cities_results.append(weather_response)
        
        
    except:
        print(f"No City Data Found for {city}")
# Out:
# found alofi
# found kodiak
# found mataura
# found najran
# found pacific grove
# found ribeira grande
# found atuona
# found guerrero negro
# found port alfred
# found hambantota
# found rikitea
# found ugoofaaru
# found jamestown
# found nikolskoye
# found amol
# found pangnirtung
# found klaksvik
# found auburn
# found russell
# found manta
# found nizhneyansk
# No City Data Found for nizhneyansk
# found avarua
# found itarema
# found shetpe
# found lompoc
# found kawalu
# found khatanga
# found namatanai
# found tasiilaq
# found frumoasa
# found bila tserkva
# found bluff
# found hilo
# found almaznyy
# found vredendal
# found leningradskiy
# found ilulissat
# found georgetown
# found bredasdorp
# found airai
# found adrar
# found east london
# found cherskiy
# found meulaboh
# found komsomolskiy
# found hobyo
# found belushya guba
# No City Data Found for belushya guba
# found megion
# found solovetskiy
# No City Data Found for solovetskiy
# found anchorage
# found kijang
# found ust-kamchatsk
# No City Data Found for ust-kamchatsk
# found butaritari
# found castro
# found illoqqortoormiut
# No City Data Found for illoqqortoormiut
# found victor harbor
# found barrow
# found poltavka
# found albany
# found omsukchan
# found skowhegan
# found nizhniy kuranakh
# found cayenne
# found longyearbyen
# found tikrit
# found ushuaia
# found henties bay
# found zapolyarnyy
# found helena
# found liku
# found vilhena
# found richards bay
# found punta arenas
# found scarborough
# found tahoua
# found portland
# found kruisfontein
# found tuktoyaktuk
# found kvarkeno
# found visnes
# found jambi
# found bethel
# found tidore
# No City Data Found for tidore
# found bud
# found halalo
# No City Data Found for halalo
# found batemans bay
# found zhuhai
# found sioux lookout
# found columbus
# found hasaki
# found kruglolesskoye
# found cape town
# found marawi
# found pondicherry
# found saint-louis
# found kuusamo
# found bambous virieux
# found taolanaro
# No City Data Found for taolanaro
# found san patricio
# found hobart
# found marcona
# No City Data Found for marcona
# found yurty
# found qaanaaq
# found coahuayana
# found dubbo
# found narsaq
# found bilma
# found vaini
# found kamenskoye
# No City Data Found for kamenskoye
# found zhaodong
# found upernavik
# found vila
# found sitka
# found mar del plata
# found bull savanna
# found paytug
# No City Data Found for paytug
# found businga
# found carnarvon
# found berkak
# found isoka
# found ejura
# found chokurdakh
# found mecca
# found lebu
# found yellowknife
# found codrington
# found rocha
# found murgab
# found kiunga
# found amla
# found hermanus
# found provideniya
# found hihifo
# No City Data Found for hihifo
# found dana point
# found turukhansk
# found laguna
# found busselton
# found uray
# found puerto ayora
# found bagdarin
# found caravelas
# found lolua
# No City Data Found for lolua
# found vrises
# found jiangyou
# found bargal
# No City Data Found for bargal
# found eydhafushi
# found port blair
# found gulshat
# No City Data Found for gulshat
# found lavrentiya
# found clyde river
# found beringovskiy
# found dutlwe
# found lasa
# found faanui
# found mys shmidta
# No City Data Found for mys shmidta
# found port elizabeth
# found doha
# found guymon
# found evensk
# found asau
# found mahebourg
# found erenhot
# found salekhard
# found guangyuan
# found vila velha
# found cabo san lucas
# found saldanha
# found jacareacanga
# found prachuap khiri khan
# found alexandria
# found berlevag
# found fairview
# found sept-iles
# found khormuj
# No City Data Found for khormuj
# found aldan
# found victoria
# found kangaatsiaq
# found kapaa
# found severo-kurilsk
# found thompson
# found arraial do cabo
# found tarudant
# No City Data Found for tarudant
# found rio brilhante
# found pisco
# found torbay
# found verkhnyaya salda
# found kargasok
# found haines junction
# found charyshskoye
# found salalah
# found paradwip
# No City Data Found for paradwip
# found saint-philippe
# found talara
# found puntarenas
# found souillac
# found roura
# found kununurra
# found ngukurr
# No City Data Found for ngukurr
# found hammerfest
# found amderma
# No City Data Found for amderma
# found yuxia
# found bengkulu
# found pizarro
# found touros
# found vrangel
# found diego de almagro
# found quballat
# found san quintin
# found beisfjord
# found new norfolk
# found cuamba
# found shihezi
# found jiblah
# found olinda
# found pilao arcado
# No City Data Found for pilao arcado
# found vestmannaeyjar
# found khandagayty
# found saint pete beach
# found comodoro rivadavia
# found chernyshevskiy
# found boditi
# found sharan
# found havelock
# found vaitape
# found lata
# found chuy
# found saint-augustin
# found karamay
# No City Data Found for karamay
# found sao jose da coroa grande
# found paamiut
# found chunskiy
# found molina
# found tura
# found yaan
# found omboue
# found kupang
# found syamzha
# found ambon
# found alpena
# found dehloran
# found ostrovnoy
# found sur
# found osorno
# found beloha
# found fuyang
# found karkaralinsk
# No City Data Found for karkaralinsk
# found havre-saint-pierre
# found dawson creek
# found ojinaga
# found porto santo
# found fez
# found bossangoa
# found puerto escondido
# found sarakhs
# found tilichiki
# found tsihombe
# No City Data Found for tsihombe
# found grand river south east
# No City Data Found for grand river south east
# found makurdi
# found castel san giovanni
# found moranbah
# found khash
# found constitucion
# found hailey
# found requena
# found sentyabrskiy
# No City Data Found for sentyabrskiy
# found muisne
# found barentsburg
# No City Data Found for barentsburg
# found snyder
# found tucumcari
# found mahon
# found ponta do sol
# found sananduva
# found imbituba
# found san pelayo
# found wasilla
# found pevek
# found gweta
# found opuwo
# found shar
# found biak
# found bystryy istok
# found de-kastri
# found maku
# found te anau
# found bintulu
# found tailai
# found allahabad
# found esna
# found port macquarie
# found bathsheba
# found dawlatabad
# found fairbanks
# found kevsala
# found acajutla
# found bachatskiy
# found kaitangata
# found ossora
# found carauari
# found palembang
# found saint george
# found iqaluit
# found nyagan
# found lysyanka
# found racine
# found vestmanna
# found jizan
# found mandalgovi
# found pittsfield
# found alice springs
# found kavieng
# found sao filipe
# found askiz
# found karratha
# found buta
# found savonlinna
# found muros
# found shenjiamen
# found kazalinsk
# No City Data Found for kazalinsk
# found tautira
# found makakilo city
# found thunder bay
# found abdanan
# found salym
# found bouar
# found aflu
# No City Data Found for aflu
# found menongue
# found azare
# found eaubonne
# found coquimbo
# found hithadhoo
# found lagoa
# found rungata
# No City Data Found for rungata
# found sambava
# found cidreira
# found koumac
# found talnakh
# found shawinigan
# found ampanihy
# found vostok
# found crab hill
# No City Data Found for crab hill
# found eslov
# found tucuman
# found brae
# found marovoay
# found sinjai
# found dikson
# found warqla
# No City Data Found for warqla
# found nemuro
# found luderitz
# found kieta
# found tari
# found valleyview
# found viedma
# found esperance
# found porto novo
# found nouadhibou
# found jiayuguan
# found wajir
# found byron bay
# found tigil
# found jalu
# found san andres
# found coihaique
# found osa
# found geraldton
# found doctor pedro p. pena
# No City Data Found for doctor pedro p. pena
# found lorengau
# found wanning
# found varkaus
# found pandan
# found santa vitoria do palmar
# found mentougou
# found gorom-gorom
# found fare
# found say
# found la romana
# found anloga
# found buin
# found kenora
# found bonthe
# found flinders
# found kushima
# found alta floresta
# found burley
# found kurchum
# found caucaia
# found saskylakh
# found bafia
# found lososina
# found tynset
# found poum
# found cajamarca
# found miraflores
# found axim
# found buraydah
# found nago
# found kawardha
# found saleaula
# No City Data Found for saleaula
# found ust-kulom
# found ulladulla
# found ishigaki
# found kempele
# found tuatapere
# found huron
# found babanusah
# No City Data Found for babanusah
# found garowe
# found ambilobe
# found porto walter
# found banda aceh
# found vao
# found yarkovo
# found samusu
# No City Data Found for samusu
# found yerofey pavlovich
# found straumen
# found yate
# found saint anthony
# found korla
# found nador
# found deputatskiy
# found khandyga
# found cap malheureux
# found nakama
# found raudeberg
# found sorland
# found kysyl-syr
# found hovd
# found ixtapa
# found macaboboni
# No City Data Found for macaboboni
# found saint-pierre
# found anar darreh
# No City Data Found for anar darreh
# found laem sing
# found san antonio
# found faya
# found matara
# found kiisa
# found waipawa
# found savinka
# found los llanos de aridane
# found hamilton
# found boca do acre
# found xining
# found algeciras
# found tarauaca
# found areia branca
# found qingdao
# found westport
# found abu jubayhah
# No City Data Found for abu jubayhah
# found gilbues
# found attawapiskat
# No City Data Found for attawapiskat
# found port hedland
# found rongcheng
# found tiksi
# found acarau
# found mandiana
# found tecoanapa
# found lamu
# found safaga
# found palafrugell
# found belaya gora
# found tabiauea
# No City Data Found for tabiauea
# found la palma
# found rio casca
# found saint-joseph
# found emborion
# found odweyne
# found saquisili
# found nha trang
# found san isidro
# found chegdomyn
# found jiwani
# found bella union
# found palora
# found guadalupe y calvo
# found sedelnikovo
# No City Data Found for sedelnikovo
# found sao raimundo das mangabeiras
# found san francisco del mar
# found jabiru
# No City Data Found for jabiru
# found sao felix do xingu
# found okhotsk
# found healesville
# found san vicente
# found arlit
# found sola
# found atlantis
# found grand-lahou
# found santa maria da boa vista
# found katsuura
# found liangxiang
# found ottawa
# found ruatoria
# No City Data Found for ruatoria
# found kraksaan
# found camacha
# found lantapan
# found shitkino
# found san policarpo
# found broken hill
# found graham
# found walvis bay
# found cervo
# found boa vista
# found lieto
# found kytlym
# No City Data Found for kytlym
# found sayanskiy
# No City Data Found for sayanskiy
# found nelson bay
# found cockburn town
# found bonavista
# found akonolinga
# found whitehorse
# found conde
# found buariki
# No City Data Found for buariki
# found reo
# found maloshuyka
# No City Data Found for maloshuyka
# found van wert
# found buluang
# found oistins
# found saint paul
# found sao joao da barra
# found gijon
# found puerto maldonado
# found sistranda
# found talcahuano
# found palabuhanratu
# No City Data Found for palabuhanratu
# found beroroha
# found zhigansk
# found shambu
# found miramar
# found thap than
# found hofn
# found aklavik
# found villa maria
# found gornopravdinsk
# found bulgan
# found srivardhan
# found fortuna
# found primorsk
# found zambezi
# found aleksandro-nevskiy
# found barstow
# found fukuchiyama
# found dekoa
# No City Data Found for dekoa
# found kahului
# found fethiye
# found mount isa
# found amboasary
# found koshurnikovo
# found patacamaya
# found buala
# found urucara
# found grindavik
# found gat
# found moa
# found taltal
# found rawson
# found nyurba
# found ancud
# found arzgir
# found bandar-e lengeh
# found redcar
# found vaitupu
# No City Data Found for vaitupu
# found abai
# found bandarbeyla
# found husavik
# found avera
# found aleksandrov gay
# found matai
# found gorontalo
# found mountain home
# found horsham
# found brownwood
# found dudinka
# found salamiyah
# found homer
# found serchhip
# found batagay
# found khromtau
# found knysna
# found eloy
# found ciudad bolivar
# found barcelos
# found margate
# found sinkat
# No City Data Found for sinkat
# found merritt
# found mainit
# found katobu
# found lyubech
# found ahipara
# found saint-francois
# found san clemente
# found mega
# found rio grande
# found koulamoutou
# found gayny
# found padang
# found el seibo
# found seryshevo
# found mumford
# found san jeronimo
# found sadovoye
# found prabumulih
# found mahajanga
# found peniche
# found ambanja
# found hansi
# found ayotzintepec
# found suhbaatar
# found reconquista
# found nuuk
# found olutanga
# found atambua
# found halifax
# found lugovoy
# found nicoya
# found shimoda
# found yuzhno-kurilsk
# found dormidontovka
# found phan rang
# No City Data Found for phan rang
# found nanortalik
# found den helder
# found marsh harbour
# found jieshi
# found murmashi
# found herat
# found keuruu
# found noumea
# found seoul
# found zyryanka
# found tsabong
# found ferkessedougou
# found champerico
# found mangrol
# found kutum

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
len(cities_results)
# Out:
# 577

# %%
city_data = []
for i,city in enumerate(cities_results):
    cityname = city["name"]
    citytemp = city["main"]["temp"]
    citymtemp = city["main"]["temp_max"]
    citylat = city["coord"]["lat"]
    cityhum = city["main"]["humidity"]
    citycloud = city["clouds"]["all"]
    citywind = city["wind"]["speed"]
    city_data.append(
        {"City": cityname,
        "Temperature": citytemp,
        "Max Temp": citymtemp,
        "Latitude": citylat,
        "Humidity %" : cityhum,
        "Cloudiness %" : citycloud,
        "Wind Speed" : citywind
        })

# %%
cities_res_df = pd.DataFrame(city_data)

# %%
cities_res_df
# Out:
#                   City  Temperature  Max Temp  Latitude  Humidity %  \
# 0                Alofi        78.80     78.80    -19.06          94
# 1    Saint Paul Harbor        21.20     21.20     57.79          92
# 2              Mataura        70.00     70.00    -46.19          61
# 3               Najrān        60.80     60.80     17.49          36
# 4        Pacific Grove        57.45     57.99     36.62          44
# ..                 ...          ...       ...       ...         ...
# 572            Tsabong        81.45     81.45    -26.02          47
# 573     Ferkessédougou        82.69     82.69      9.60          43
# 574         Champerico        81.90     89.60     14.30          59
# 575            Māngrol        67.35     67.35     21.12          56
# 576              Kutum        55.83     55.83     14.20          36
#
#      Cloudiness %  Wind Speed
# 0              75        8.05
# 1               1        8.05
# 2              91       11.01
# 3               0        0.69
# 4               1        5.82
# ..            ...         ...
# 572            31       19.33
# 573            56        6.13
# 574            40        6.93
# 575            17        9.86
# 576            12        6.82
#
# [577 rows x 7 columns]

# %% [markdown]
# cities_res_df

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

'100' in cities_res_df.values
# Out:
# False

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
N/A

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#Scatterplot showing the Latitude vs. Temperature

latitude = cities_res_df.iloc[:,3]
temperature = cities_res_df.iloc[:,1]
edgecolors = ['black']
plt.scatter(latitude, temperature, edgecolors=edgecolors)
plt.title("City Latitude vs. Temperature")
plt.xlabel("Latitude")
plt.ylabel("Temperature")
plt.grid(b=True)
plt.show()

# %% [markdown]
# This Scatter Plot shows that the temperatures on this day indicate cities in the Northern Hemisphere are warmer.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
latitude = cities_res_df.iloc[:,3]
humidity = cities_res_df.iloc[:,4]
edgecolors = ['black']
plt.scatter(latitude, humidity, edgecolors=edgecolors)
plt.title("City Latitude vs. Humidity %")
plt.xlabel("Latitude")
plt.ylabel("Humidity %")
plt.grid(b=True)
plt.show()

# %% [markdown]
# This Scatter Plot measures the the city's Latitude from the Equator/Prime Meridian relative to Humidity

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
latitude = cities_res_df['Latitude']
cloudiness = cities_res_df['Cloudiness %']
edgecolors = ['black']
plt.scatter(latitude, cloudiness, edgecolors=edgecolors)
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid(b=True)
plt.show()

# %% [markdown]
# This Scatter Plot show that Cloudiness appear equal relative to Latitude

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
latitude = cities_res_df['Latitude']
windspeed = cities_res_df['Wind Speed']
edgecolors = ['black']
plt.scatter(latitude, windspeed, edgecolors=edgecolors)
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid(b=True)
plt.show()

# %% [markdown]
# This Scatter Plot appers to indicate that Cities Latitude does not have a correlation to Wind Speed

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
maxtemp = cities_res_df['Max Temp']
nlatitude = cities_res_df['Latitude']
edgecolors = ['black']
(slope, intercept, rvalue, pvalue, stderr) = linregress(maxtemp, latitude)
regress_values = maxtemp * slope + intercept
line_eq = "Latitude = " + str(round(slope,2)) + "Maxtemp + " + str(round(intercept,2))
plt.scatter(maxtemp, latitude, edgecolors=edgecolors)
plt.plot(maxtemp,regress_values,"r-")
plt.annotate(line_eq,(-40,-20),fontsize=15,color="red")
plt.title("Max Temp and Latitude Regression Study")
plt.xlabel("Max Temp")
plt.ylabel("Latitude")
plt.grid(b=True)
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
maxtemp = cities_res_df['Max Temp']
latitude = cities_res_df['Latitude']
edgecolors = ['black']
(slope, intercept, rvalue, pvalue, stderr) = linregress(maxtemp, latitude)
regress_values = maxtemp * slope + intercept
line_eq = "Latitude = " + str(round(slope,-2)) + "Maxtemp + " + str(round(intercept,-2))
plt.scatter(maxtemp, latitude, edgecolors=edgecolors)
plt.plot(maxtemp,regress_values,"r-")
plt.annotate(line_eq,(-40,-20),fontsize=15,color="red")
plt.title("Max Temp and Latitude Regression Study")
plt.xlabel("Max Temp")
plt.ylabel("Latitude")
plt.grid(b=True)
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
humidity = cities_res_df['Humidity %']
latitude = cities_res_df['Latitude']
edgecolors = ['black']
(slope, intercept, rvalue, pvalue, stderr) = linregress(humidity, latitude)
regress_values = humidity * slope + intercept
line_eq = "Laitude = " + str(round(slope,2)) + "Humidity + " + str(round(intercept,2))
plt.scatter(humidity, latitude, edgecolors=edgecolors)
plt.plot(humidity,regress_values,"r-")
plt.annotate(line_eq,(20,-60),fontsize=15,color="red")
plt.title("Humidity % and Latitude Regression Study")
plt.xlabel("Humidity%")
plt.ylabel("Latitude")
plt.grid(b=True)
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
humidity = cities_res_df['Humidity %']
latitude = cities_res_df['Latitude']
edgecolors = ['black']
(slope, intercept, rvalue, pvalue, stderr) = linregress(humidity, latitude)
regress_values = humidity * slope + intercept
line_eq = "Latitude = " + str(round(slope,2)) + "Humidity + " + str(round(intercept,2))
plt.scatter(humidity, latitude, edgecolors=edgecolors)
plt.plot(humidity,regress_values,"r-")
plt.annotate(line_eq,(20,-60),fontsize=15,color="red")
plt.title("Humidity % and Latitude Regression Study")
plt.xlabel("Humidity%")
plt.ylabel("Latitude")
plt.grid(b=True)
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
cloudiness = cities_res_df['Cloudiness %']
latitude = cities_res_df['Latitude']
edgecolors = ['black']
(slope, intercept, rvalue, pvalue, stderr) = linregress(cloudiness, latitude)
regress_values = cloudiness * slope + intercept
line_eq = "Latitude = " + str(round(slope,2)) + "Cloudiness + " + str(round(intercept,2))
plt.scatter(cloudiness, latitude, edgecolors=edgecolors)
plt.plot(cloudiness,regress_values,"r-")
plt.annotate(line_eq,(0,-60),fontsize=15,color="red")
plt.title("Cloudiness % and Latitude Regression Study")
plt.xlabel("Cloudiness %")
plt.ylabel("Latitude")
plt.grid(b=True)
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
cloudiness = cities_res_df['Cloudiness %']
latitude = cities_res_df['Latitude']
edgecolors = ['black']
(slope, intercept, rvalue, pvalue, stderr) = linregress(cloudiness, latitude)
regress_values = cloudiness * slope + intercept
line_eq = "Latitude = " + str(round(slope,2)) + "Cloudiness + " + str(round(intercept,2))
plt.scatter(cloudiness, latitude, edgecolors=edgecolors)
plt.plot(cloudiness,regress_values,"r-")
plt.annotate(line_eq,(0,-60),fontsize=15,color="red")
plt.title("Cloudiness % and Latitude Regression Study")
plt.xlabel("Cloudiness %")
plt.ylabel("Latitude")
plt.grid(b=True)
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
windspeed = cities_res_df['Wind Speed']
latitude = cities_res_df['Latitude']
edgecolors = ['black']
(slope, intercept, rvalue, pvalue, stderr) = linregress(windspeed, latitude)
regress_values = cloudiness * slope + intercept
line_eq = "Latitude = " + str(round(slope,2)) + "Cloudiness + " + str(round(intercept,2))
plt.scatter(cloudiness, latitude, edgecolors=edgecolors)
plt.plot(cloudiness,regress_values,"r-")
plt.annotate(line_eq,(0,-60),fontsize=15,color="red")
plt.title("Cloudiness % and Latitude Regression Study")
plt.xlabel("Cloudiness %")
plt.ylabel("Latitude")
plt.grid(b=True)
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
windspeed = cities_res_df['Wind Speed']
latitude = cities_res_df['Latitude']
edgecolors = ['black']
(slope, intercept, rvalue, pvalue, stderr) = linregress(windspeed, latitude)
regress_values = cloudiness * slope + intercept
line_eq = "Latitude = " + str(round(slope,2)) + "Cloudiness + " + str(round(intercept,2))
plt.scatter(cloudiness, latitude, edgecolors=edgecolors)
plt.plot(cloudiness,regress_values,"r-")
plt.annotate(line_eq,(0,-60),fontsize=15,color="red")
plt.title("Cloudiness % and Latitude Regression Study")
plt.xlabel("Cloudiness %")
plt.ylabel("Latitude")
plt.grid(b=True)
plt.show()
