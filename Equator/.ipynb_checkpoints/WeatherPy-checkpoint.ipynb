# %% [markdown]
# ## WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# !pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\michelle\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\michelle\anaconda3\lib\site-packages (from citipy) (0.16)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import logging
import math

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

lat_lngs

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 611

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it's being processed (with the city number and city name).

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather?"
city = cities


query_url = f"{base_url}appid={weather_api_key}&q={city}&units=imperial"

# Get weather data
#weather_response = requests.get(query_url).json()

# %%
cities_results = []

#Conversion of Kelvin to Fahrenheit


for index,city in enumerate(cities):
    
    base_url = "http://api.openweathermap.org/data/2.5/weather?"
    query_url = f"{base_url}appid={weather_api_key}&q={city}&units=imperial"

    print(f'found {city}')
          
    try:
        # Get weather data
        weather_response = requests.get(query_url).json()
        lon=weather_response["coord"]["lon"]
        lat=weather_response["coord"]["lat"]
        cities_results.append(weather_response)
        
        
    except:
        print(f"No City Data Found for {city}")
# Out:
# found sao filipe
# found manokwari
# found rikitea
# found vaini
# found nizhniy ingash
# found illoqqortoormiut
# No City Data Found for illoqqortoormiut
# found hermanus
# found ushuaia
# found kimberley
# found meulaboh
# found siguiri
# found bethel
# found nikolskoye
# found jamestown
# found constitucion
# found upernavik
# found asadabad
# found butaritari
# found tasiilaq
# found atuona
# found carauari
# found maniitsoq
# found kodiak
# found rolim de moura
# No City Data Found for rolim de moura
# found ponta do sol
# found peace river
# found albany
# found caravelas
# found thompson
# found port elizabeth
# found virginia beach
# found puerto suarez
# found saint-philippe
# found killybegs
# found manakara
# found sobolevo
# found tubruq
# No City Data Found for tubruq
# found coihaique
# found wattegama
# found chuy
# found teknaf
# found taolanaro
# No City Data Found for taolanaro
# found nanortalik
# found pakxan
# found petropavlovsk-kamchatskiy
# found minot
# found rawson
# found pisco
# found narsaq
# found kahului
# found padang
# found mataura
# found bredasdorp
# found puerto ayora
# found punta arenas
# found saint george
# found bolungarvik
# No City Data Found for bolungarvik
# found tuatapere
# found macae
# found bambous virieux
# found busselton
# found san jose
# found russellville
# found kaitangata
# found tuktoyaktuk
# found cabo san lucas
# found coquimbo
# found alofi
# found chokurdakh
# found lagoa
# found haines junction
# found novyy urengoy
# found kihei
# found port alfred
# found khatanga
# found kuna
# found sataua
# No City Data Found for sataua
# found avera
# found klaksvik
# found madawaska
# found pevek
# found lata
# found port blair
# found barrow
# found victoria
# found dudinka
# found carballo
# found avarua
# found mabaruma
# found hvammstangi
# No City Data Found for hvammstangi
# found medeiros neto
# found beidao
# found mandalgovi
# found husavik
# found tual
# found kapaa
# found hobyo
# found sao felix do xingu
# found bereda
# found grand river south east
# No City Data Found for grand river south east
# found nacala
# found lerwick
# found hobart
# found cidreira
# found kavieng
# found douentza
# found cape town
# found agirish
# found filadelfia
# found borsa
# found barentsburg
# No City Data Found for barentsburg
# found leningradskiy
# found jinka
# found sucre
# found belushya guba
# No City Data Found for belushya guba
# found atar
# found alice springs
# found airai
# found georgetown
# found buchanan
# found yellowknife
# found severo-kurilsk
# found hilo
# found broken hill
# found provideniya
# found tiksi
# found umm durman
# No City Data Found for umm durman
# found bengkulu
# found adrar
# found seoul
# found aswan
# found deputatskiy
# found castro
# found bull savanna
# found sandwich
# found attawapiskat
# No City Data Found for attawapiskat
# found dar es salaam
# found sao joao da barra
# found saleaula
# No City Data Found for saleaula
# found ahipara
# found urusha
# found pangody
# found karaul
# No City Data Found for karaul
# found timizart
# found santa rita
# found erseke
# found vestmannaeyjar
# found ngukurr
# No City Data Found for ngukurr
# found saskylakh
# found port hardy
# found dikson
# found dauphin
# found ayan
# found mana
# found aripuana
# found selimpasa
# found krasnoselkup
# found richards bay
# found tumannyy
# No City Data Found for tumannyy
# found moose factory
# found mahebourg
# found college
# found ribeira grande
# found new norfolk
# found iqaluit
# found zhigansk
# found othaya
# found karratha
# found grande prairie
# found kalmunai
# found pacific grove
# found atbasar
# found lompoc
# found dobanovci
# found bluff
# found cabedelo
# found mar del plata
# found qaanaaq
# found impfondo
# found ganzhou
# found tommot
# found manzil tamim
# No City Data Found for manzil tamim
# found carnarvon
# found vasylivka
# found culpeper
# found cherskiy
# found matamoros
# found hami
# found sinop
# found kyabe
# found igarapava
# found asifabad
# found algiers
# found arraial do cabo
# found sabha
# found hithadhoo
# found la paz
# found zyryanka
# found faya
# found eureka
# found karkaralinsk
# No City Data Found for karkaralinsk
# found narrabri
# found hasaki
# found samdrup jongkhar
# found mombetsu
# found naugarzan
# No City Data Found for naugarzan
# found olafsvik
# found svarstad
# found christchurch
# found viedma
# found east london
# found ola
# found bilibino
# found washington
# found itarema
# found vostok
# found calvinia
# found carbonia
# found mayumba
# found sorong
# found gannan
# found saldanha
# found katherine
# found bambanglipuro
# found taoudenni
# found ndioum
# found lagos
# found kimbe
# found dingle
# found kaeo
# found cedar city
# found torbay
# found da lat
# found bangassou
# found samalaeulu
# No City Data Found for samalaeulu
# found moa
# found lorengau
# found ambulu
# found touros
# found saint anthony
# found sentyabrskiy
# No City Data Found for sentyabrskiy
# found san juan del sur
# found kununurra
# found katy
# found port arthur
# found ternate
# found varzea da palma
# found eluru
# found hamilton
# found calabar
# found sambava
# found murwillumbah
# found warqla
# No City Data Found for warqla
# found faanui
# found bargal
# No City Data Found for bargal
# found abu samrah
# found esperance
# found mys shmidta
# No City Data Found for mys shmidta
# found vardo
# found paso de los toros
# found tarko-sale
# found quirinopolis
# found goderich
# found dukat
# found shache
# found kibaek
# found kogon
# found inhambane
# found huarmey
# found amderma
# No City Data Found for amderma
# found reconquista
# found bossembele
# No City Data Found for bossembele
# found samusu
# No City Data Found for samusu
# found soyo
# found kyrylivka
# found vidim
# found luanda
# found asau
# found honiara
# found luderitz
# found tura
# found kudat
# found hualmay
# found aksarka
# found banjarmasin
# found talnakh
# found meyungs
# No City Data Found for meyungs
# found atliaca
# found ugoofaaru
# found fortuna
# found brae
# found pemberton
# found laguna
# found erenhot
# found piacabucu
# found grindavik
# found saint-pierre
# found san jeronimo
# found cervo
# found corrente
# found port-gentil
# found kloulklubed
# found mayor pablo lagerenza
# found kiknur
# found maarianhamina
# found zaysan
# found hambantota
# found shingu
# found dolores hidalgo
# found margate
# found vaitupu
# No City Data Found for vaitupu
# found aklavik
# found la ronge
# found khormuj
# No City Data Found for khormuj
# found udachnyy
# found davila
# found aguimes
# found vila franca do campo
# found fairbanks
# found porto murtinho
# found isangel
# found labuhan
# found nouakchott
# found rosetown
# found collie
# found wenling
# found vytegra
# found reston
# found katsuura
# found safaga
# found koriyama
# found katobu
# found kyzyl-suu
# found tabuleiro do norte
# found wangou
# found pangnirtung
# found lac du bonnet
# found lima
# found yerbogachen
# found taunggyi
# found cockburn town
# found alta floresta
# found fairview
# found mehamn
# found santa isabel do rio negro
# found urosevac
# No City Data Found for urosevac
# found sioux lookout
# found labytnangi
# found iguape
# found porto belo
# found clocolan
# found vao
# found kerouane
# found khorramshahr
# found charters towers
# found okha
# found tyrma
# found yinchuan
# found rocha
# found bubaque
# found pena
# found orange
# found sur
# found morada nova
# found jiuquan
# found serafimovich
# found sorland
# found roma
# found takoradi
# found junin
# found zumpahuacan
# found surman
# found necochea
# found berlevag
# found helong
# found awjilah
# found borama
# No City Data Found for borama
# found salalah
# found susanville
# found wakefield
# found inderborskiy
# No City Data Found for inderborskiy
# found norilsk
# found saint-francois
# found saharanpur
# found nicoya
# found longyearbyen
# found baiyin
# found ordzhonikidze
# found talcahuano
# found jinxiang
# found korla
# found san carlos de bariloche
# found wildeshausen
# found stuttgart
# found elk plain
# found akureyri
# found dhidhdhoo
# found tambul
# No City Data Found for tambul
# found toliary
# No City Data Found for toliary
# found otjimbingwe
# found north bend
# found keningau
# found nioro
# found ilulissat
# found marawi
# found dhandhuka
# found lebu
# found berezovka
# found portland
# found sao miguel do araguaia
# found basco
# found suntar
# found wasilla
# found norman wells
# found domoni
# found kokstad
# found uniara
# found saint-andre-avellin
# found galveston
# found souillac
# found samarai
# found churachandpur
# found vyssi brod
# found vanimo
# found naze
# found mackay
# found mandera
# found clyde river
# found yugorsk
# found ancud
# found songkhla
# found grand centre
# No City Data Found for grand centre
# found walvis bay
# found tucurui
# found chernyshevskiy
# found cancun
# found qazvin
# found boden
# found tarumovka
# found nizhneyansk
# No City Data Found for nizhneyansk
# found edera de jos
# No City Data Found for edera de jos
# found florissant
# found karaton
# found tingi
# found tautira
# found nueva concepcion
# found tsihombe
# No City Data Found for tsihombe
# found boyolangu
# found kirakira
# found jumla
# found santa rosa
# found ust-uda
# found raga
# found havre-saint-pierre
# found kysyl-syr
# found tessalit
# found khuzdar
# found san borja
# found villa guerrero
# found xining
# found yulara
# found makokou
# found ciudad bolivar
# found sibolga
# found twentynine palms
# found kargopol
# found decatur
# found danilov
# found saint-joseph
# found usinsk
# found halifax
# found havelock
# found lahaina
# found yaan
# found sisimiut
# found pacocha
# found ibia
# found port macquarie
# found ixtapa
# found saint-georges
# found mehar
# found longhua
# found marsa matruh
# found verkhnyaya inta
# found sindor
# found tubuala
# found murgab
# found te anau
# found codrington
# found tanete
# found mauraro
# found shimoda
# found igarka
# found bocas del toro
# found harper
# found kula
# found ostrovnoy
# found axim
# found genhe
# found meybod
# found acuna
# No City Data Found for acuna
# found biak
# found viligili
# No City Data Found for viligili
# found prince rupert
# found codajas
# found valreas
# found borovoy
# found mahon
# found oktyabrskoye
# found ada
# found estevan
# found damghan
# found sinnamary
# found linchuan
# No City Data Found for linchuan
# found lincoln
# found vila velha
# found nyagan
# found balkhash
# found san quintin
# found dergachi
# found poshekhonye
# found bayir
# found mayskiy
# found strezhevoy
# found petropavl
# found alexandria
# found bolshoy lug
# found la plaine
# found wahiawa
# found cerro largo
# found paytug
# No City Data Found for paytug
# found kenai
# found kharabali
# found mushie
# found phibun mangsahan
# found sept-iles
# found mayo
# found camapua
# found oranjemund
# found forestville
# found inta
# found los llanos de aridane
# found leh
# found ardistan
# No City Data Found for ardistan
# found fort saint john
# No City Data Found for fort saint john
# found dwarka
# found fauske
# found howard springs
# found libres
# found namibe
# found port hedland
# found komsomolets
# found buraydah
# found hayrabolu
# found camacha
# found san patricio
# found gushikawa
# found srednekolymsk
# found snezhnogorsk
# found koroni
# found maragogi
# found kruisfontein
# found innisfail
# found pilar
# found karabulak
# found najran
# found bemidji
# found coulihaut
# No City Data Found for coulihaut
# found flin flon
# found burgeo
# found mount isa
# found cayenne
# found hakkari
# found sistranda
# found derzhavinsk
# found bella union
# found homer
# found coatlan
# No City Data Found for coatlan
# found kavaratti
# found san francisco de macoris
# found belsand
# found douglas
# found yabelo
# found vredendal
# found macaboboni
# No City Data Found for macaboboni
# found labutta
# No City Data Found for labutta
# found andalan
# found dunedin
# found deh rawud
# No City Data Found for deh rawud
# found lishu
# found toamasina
# found kizhinga
# found newport
# found ust-kuyga
# found taraza
# found the valley
# found yanan
# No City Data Found for yanan
# found alcudia
# found half moon bay
# found praia
# found verkhniye tatyshly
# found karamea
# No City Data Found for karamea
# found abonnema
# found usoke
# found storsteinnes
# found garbolovo
# found kholm
# found coruripe
# found bridlington
# found reefton
# No City Data Found for reefton
# found myaundzha

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
len(cities_results)
# Out:
# 558

# %%
city_data = []
for i,city in enumerate(cities_results):
    cityname = city["name"]
    citytemp = city["main"]["temp"]
    citymtemp = city["main"]["temp_max"]
    citylat = city["coord"]["lat"]
    cityhum = city["main"]["humidity"]
    citycloud = city["clouds"]["all"]
    citywind = city["wind"]["speed"]
    city_data.append(
        {"City": cityname,
        "Temperature": citytemp,
        "Max Temp": citymtemp,
        "Latitude": citylat,
        "Humidity %" : cityhum,
        "Cloudiness %" : citycloud,
        "Wind Speed" : citywind
        })

# %%
cities_res_df = pd.DataFrame(city_data)

# %%
cities_res_df
# Out:
#                City  Temperature  Max Temp  Latitude  Humidity %  \
# 0        São Filipe        74.05     74.05     14.90          69
# 1         Manokwari        80.11     80.11     -0.87          73
# 2           Rikitea        77.16     77.16    -23.12          76
# 3             Vaini        78.80     78.80    -21.20          88
# 4    Nizhniy Ingash        19.69     19.69     56.20          97
# ..              ...          ...       ...       ...         ...
# 553       Garbolovo        35.01     35.01     60.34          95
# 554           Kholm        33.03     33.03     59.27          97
# 555        Coruripe        80.78     80.78    -10.13          71
# 556     Bridlington        42.24     42.80     54.08          87
# 557       Myaundzha       -29.36    -29.36     63.05          81
#
#      Cloudiness %  Wind Speed
# 0             100       11.95
# 1              98        6.44
# 2              42       22.64
# 3              20       11.41
# 4             100        5.84
# ..            ...         ...
# 553           100        8.77
# 554           100        6.17
# 555            46       18.28
# 556             0        9.17
# 557            94        1.92
#
# [558 rows x 7 columns]

# %% [markdown]
# cities_res_df

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

'100' in cities_res_df.values
# Out:
# False

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
N/A
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-03c5ccccc6ae> in <module>
# ----> 1 N/A
#
# NameError: name 'N' is not defined

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#Scatterplot showing the Latitude vs. Temperature

latitude = cities_res_df.iloc[:,3]
temperature = cities_res_df.iloc[:,1]
edgecolors = ['black']
plt.scatter(latitude, temperature, edgecolors=edgecolors)
plt.title("City Latitude vs. Temperature")
plt.xlabel("Latitude")
plt.ylabel("Temperature")
plt.grid(b=True)
plt.show()

# %% [markdown]
# This Scatter Plot shows that the temperatures on this day indicate cities in the Northern Hemisphere are warmer.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
latitude = cities_res_df.iloc[:,3]
humidity = cities_res_df.iloc[:,4]
edgecolors = ['black']
plt.scatter(latitude, humidity, edgecolors=edgecolors)
plt.title("City Latitude vs. Humidity %")
plt.xlabel("Latitude")
plt.ylabel("Humidity %")
plt.grid(b=True)
plt.show()

# %% [markdown]
# This Scatter Plot measures the the city's Latitude from the Equator/Prime Meridian relative to Humidity

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
latitude = cities_res_df['Latitude']
cloudiness = cities_res_df['Cloudiness %']
edgecolors = ['black']
plt.scatter(latitude, cloudiness, edgecolors=edgecolors)
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid(b=True)
plt.show()

# %% [markdown]
# This Scatter Plot show that Cloudiness appear equal relative to Latitude

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
latitude = cities_res_df['Latitude']
windspeed = cities_res_df['Wind Speed']
edgecolors = ['black']
plt.scatter(latitude, windspeed, edgecolors=edgecolors)
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid(b=True)
plt.show()

# %% [markdown]
# This Scatter Plot appers to indicate that Cities Latitude does not have a correlation to Wind Speed

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
maxtemp = cities_res_df.loc[cities_res_df["Latitude"] >= 0.0]['Max Temp']
northlat = cities_res_df.loc[cities_res_df["Latitude"] >= 0.0]['Latitude']
edgecolors = ['black']
(slope, intercept, rvalue, pvalue, stderr) = linregress(maxtemp, northlat)
regress_values = maxtemp * slope + intercept
line_eq = " Latitude = " + str(round(slope,-2)) + "Maxtemp + " + str(round(intercept,-2))
plt.scatter(maxtemp, northlat, edgecolors=edgecolors)
plt.plot(maxtemp,regress_values,"r-")
plt.annotate(line_eq,(-40,-0),fontsize=15,color="red"),
plt.title("Max Temp and Latitude Regression Study")
plt.xlabel("Max Temp")
plt.ylabel("Latitude")
plt.grid(b=True)
plt.show()

# %%
This regression reveals that cities closest to the equator in the Northern Hemisphere have the highest temperatires.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
maxtemp = cities_res_df.loc[cities_res_df["Latitude"] < 0.0]['Max Temp']
southlat = cities_res_df.loc[cities_res_df["Latitude"] < 0.0]['Latitude']
edgecolors = ['black']
(slope, intercept, rvalue, pvalue, stderr) = linregress(maxtemp, southlat)
regress_values = maxtemp * slope + intercept
line_eq = "Latitude = " + str(round(slope,-2)) + "Maxtemp + " + str(round(intercept,-2))
plt.scatter(maxtemp, southlat, edgecolors=edgecolors)
plt.plot(maxtemp,regress_values,"r-")
plt.annotate(line_eq,(70,-50),fontsize=15,color="red")
plt.title("Max Temp and Latitude Regression Study")
plt.xlabel("Max Temp")
plt.ylabel("Latitude")
plt.grid(b=True)
plt.show()

# %%
This regression indicates that the temperature increases closer to the Equtor

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
humidity = cities_res_df.loc[cities_res_df["Latitude"] >= 0.0]['Humidity %']
northlat = cities_res_df.loc[cities_res_df["Latitude"] >= 0.0]['Latitude']
edgecolors = ['black']
(slope, intercept, rvalue, pvalue, stderr) = linregress(humidity, northlat)
regress_values = humidity * slope + intercept
line_eq = " Latitude = " + str(round(slope,-2)) + "Humidity + " + str(round(intercept,-2))
plt.scatter(humidity, northlat, edgecolors=edgecolors)
plt.plot(humidity,regress_values,"r-")
plt.annotate(line_eq,(0, 70),fontsize=15,color="red"),
plt.title("Humidity and Latitude Regression Study")
plt.xlabel("Humidity")
plt.ylabel("Latitude")
plt.grid(b=True)
plt.show()

# %%
This regression study indicates that the humidity increases the further north from the Equator a City is located.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
humidity = cities_res_df.loc[cities_res_df["Latitude"] < 0.0]['Humidity %']
southlat = cities_res_df.loc[cities_res_df["Latitude"] < 0.0]['Latitude']
edgecolors = ['black']
(slope, intercept, rvalue, pvalue, stderr) = linregress(humidity, southlat)
regress_values = humidity * slope + intercept
line_eq = " Latitude = " + str(round(slope,-2)) + "Humidity + " + str(round(intercept,-2))
plt.scatter(humidity, southlat, edgecolors=edgecolors)
plt.plot(humidity,regress_values,"r-")
plt.annotate(line_eq,(20, -10),fontsize=15,color="red"),
plt.title("Humidity and Regression Study")
plt.xlabel("Humidity")
plt.ylabel("Latitude")
plt.grid(b=True)
plt.show()

# %%
Regression study which indicates that humidity increaes

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
cloudiness = cities_res_df.loc[cities_res_df["Latitude"] >= 0.0]['Cloudiness %']
northlat = cities_res_df.loc[cities_res_df["Latitude"] >= 0.0]['Latitude']
edgecolors = ['black']
(slope, intercept, rvalue, pvalue, stderr) = linregress(cloudiness, northlat)
regress_values = cloudiness * slope + intercept
line_eq = " Latitude = " + str(round(slope,-2)) + "Cloudiness + " + str(round(intercept,-2))
plt.scatter(cloudiness, northlat, edgecolors=edgecolors)
plt.plot(cloudiness,regress_values,"r-")
plt.annotate(line_eq,(0, 0),fontsize=15,color="red"),
plt.title("Cloudiness and Latitude Regression Study")
plt.xlabel("Cloudiness")
plt.ylabel("Latitude")
plt.grid(b=True)
plt.show()

# %%
There does not seem to be a correlation between distance from the equator and cloudiness.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
cloudiness = cities_res_df.loc[cities_res_df["Latitude"] < 0.0]['Cloudiness %']
southlat = cities_res_df.loc[cities_res_df["Latitude"] < 0.0]['Latitude']
edgecolors = ['black']
(slope, intercept, rvalue, pvalue, stderr) = linregress(cloudiness, southlat)
regress_values = cloudiness * slope + intercept
line_eq = " Latitude = " + str(round(slope,-2)) + "Cloudiness + " + str(round(intercept,-2))
plt.scatter(cloudiness, southlat, edgecolors=edgecolors)
plt.plot(cloudiness,regress_values,"r-")
plt.annotate(line_eq,(20, -50),fontsize=15,color="red"),
plt.title("Cloudiness and Latitude Regression Study")
plt.xlabel("Cloudiness")
plt.ylabel("Latitude")
plt.grid(b=True)
plt.show()

# %%
There does not seem to be a correlation between distance from the equator and cloudiness.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
windspeed = cities_res_df.loc[cities_res_df["Latitude"] >= 0.0]['Wind Speed']
northlat = cities_res_df.loc[cities_res_df["Latitude"] >= 0.0]['Latitude']
edgecolors = ['black']
(slope, intercept, rvalue, pvalue, stderr) = linregress(windspeed, northlat)
regress_values = windspeed * slope + intercept
line_eq = " Latitude = " + str(round(slope,-2)) + "Wind Speed + " + str(round(intercept,-2))
plt.scatter(windspeed, northlat, edgecolors=edgecolors)
plt.plot(windspeed,regress_values,"r-")
plt.annotate(line_eq,(15, 0),fontsize=15,color="red"),
plt.title("Wind Speed and Latitude Regression Study")
plt.xlabel("Wind Speed")
plt.ylabel("Latitude")
plt.grid(b=True)
plt.show()

# %%
Wind Speed and proximity to the Equator does not seem to be related.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
windspeed = cities_res_df.loc[cities_res_df["Latitude"] < 0.0]['Wind Speed']
southlat = cities_res_df.loc[cities_res_df["Latitude"] < 0.0]['Latitude']
edgecolors = ['black']
(slope, intercept, rvalue, pvalue, stderr) = linregress(windspeed, southlat)
regress_values = windspeed * slope + intercept
line_eq = " Latitude = " + str(round(slope,-2)) + "Wind Speed + " + str(round(intercept,-2))
plt.scatter(windspeed, southlat, edgecolors=edgecolors)
plt.plot(windspeed,regress_values,"r-")
plt.annotate(line_eq,(30, -20),fontsize=15,color="red"),
plt.title("Wind Speed and Latitude Regression Study")
plt.xlabel("Wind Speed")
plt.ylabel("Latitude")
plt.grid(b=True)
plt.show()

# %%
Wind Speed and proximity to the Equator does not seem to be related.
